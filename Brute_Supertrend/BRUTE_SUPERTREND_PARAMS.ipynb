# %%
import pandas as pd
import numpy as np
import yfinance as yf
from itertools import product
from numba import njit

def DataFetcher(symbol, interval='1d'):
    suffixes = ['.NS', '.BO']
    for suffix in suffixes:
        try:
            data = yf.download(symbol + suffix, interval=interval, progress=False)
            data.drop(columns='Adj Close', inplace=True)
            data.rename(columns={'Open': 'open', 'High': 'high', 'Low': 'low', 'Close': 'close', 'Volume': 'volume'}, inplace=True)
            data['Time'] = data.index
            return data,symbol + suffix
        except Exception as e:
            #print(f"Failed to fetch data for {symbol+suffix}: {e}")
            continue
    return pd.DataFrame()


@njit
def calculate_supertrend_fast(high, low, close, volume, period, multiplier):
    atr = np.zeros_like(close)
    supertrend = np.zeros_like(close)
    direction = np.zeros_like(close)
    
    # Calculate ATR
    tr = np.maximum(high - low, np.abs(high - np.roll(close, 1)), np.abs(low - np.roll(close, 1)))
    atr[period-1] = np.mean(tr[:period])
    for i in range(period, len(close)):
        atr[i] = (atr[i-1] * (period - 1) + tr[i]) / period
    
    # Calculate volume factor
    volume_ma = np.zeros_like(volume)
    volume_ma[period-1] = np.mean(volume[:period])
    for i in range(period, len(volume)):
        volume_ma[i] = (volume_ma[i-1] * (period - 1) + volume[i]) / period
    volume_factor = volume / volume_ma
    
    # Calculate SuperTrend
    hl2 = (high + low) / 2
    basic_upperband = hl2 + (multiplier * atr * volume_factor)
    basic_lowerband = hl2 - (multiplier * atr * volume_factor)
    
    for i in range(period, len(close)):
        if close[i] > supertrend[i-1]:
            supertrend[i] = max(basic_lowerband[i], supertrend[i-1])
        else:
            supertrend[i] = min(basic_upperband[i], supertrend[i-1])
        
        if close[i] > supertrend[i]:
            direction[i] = 1
        else:
            direction[i] = -1

    return supertrend, direction

def calculate_super_trend(df, multiplier, period):
    supertrend, direction = calculate_supertrend_fast(
        df['high'].values, df['low'].values, df['close'].values, 
        df['volume'].values, period, multiplier
    )
    
    df['super_trend'] = supertrend
    df['signal'] = direction
    df['Position'] = df['signal'].diff()
    df['Buy/Sell'] = df['Position'].map({2: 'Buy', -2: 'Sell', 0: 'Hold'})
    df['VSMA'] = df['volume'].rolling(window=period).mean()
    
    return df




def calculate_super_trend_performance(df):
    if 'signal' not in df.columns:
      raise ValueError("Signal column not created. Check calculate_super_trend function.")

    df['returns'] = np.log(df['close'] / df['close'].shift(1))
    df['strategy'] = df['signal'].shift(1) * df['returns']
    df['creturns'] = df['returns'].cumsum().apply(np.exp)
    df['cstrategy'] = df['strategy'].cumsum().apply(np.exp)
    perf = df['cstrategy'].iloc[-1]
    buy_and_hold = df['creturns'].iloc[-1]
    outperf = perf - buy_and_hold
    return round(perf, 6), round(buy_and_hold, 6), round(outperf, 6)

def optimize_super_trend_parameters(df, multipliers, periods):
    best_performance = -np.inf
    best_params = None
    for multiplier, period in product(multipliers, periods):
        temp_df = df.copy()
        temp_df=calculate_super_trend(temp_df, multiplier, period)
        performance = calculate_super_trend_performance(temp_df)[0]
        if performance > best_performance:
            best_performance = performance
            best_params = (multiplier, period)
    return best_params

def calculate_profit_percentage(df):
    initial_principal = 100000  # Start with $100,000
    cash = initial_principal
    shares = 0

    for index, row in df.iterrows():
        if row['Buy/Sell'] == 'Buy' and cash > 0:
            shares_bought = cash // row['close']
            shares += shares_bought
            cash -= shares_bought * row['close']
        elif row['Buy/Sell'] == 'Sell' and shares > 0:
            cash += shares * row['close']
            shares = 0

    # If there are any shares left, sell them at the last recorded price
    if shares > 0:
        cash += shares * df['close'].iloc[-1]
        shares = 0

    final_principal = cash
    profit = final_principal - initial_principal
    profit_percentage = (profit / initial_principal) * 100
    return profit_percentage

def calculate_trade_percentages(df):
    # Ensure the dataframe contains 'Buy/Sell' column
    if 'Buy/Sell' not in df.columns:
        raise ValueError("Buy/Sell column not created. Check calculate_super_trend function.")
    
    # Lists to store buy and sell prices
    buy_prices = []
    sell_prices = []

    # Track the latest close value when the latest signal is 'Buy'
    latest_close = df.tail(1)['close'].values[0]  # Get the latest close value

    # Loop through the dataframe to collect buy and sell prices
    for index, row in df.iterrows():
        if row['Buy/Sell'] == 'Buy':
            buy_prices.append(row['close'])
        elif row['Buy/Sell'] == 'Sell' and buy_prices:
            sell_prices.append(row['close'])

    # Handle the case where the latest signal is 'Buy'
    if len(buy_prices) > len(sell_prices):
        sell_prices.append(latest_close)

    # Calculate percentage changes for each trade
    trade_percentages = [(sell - buy) / buy * 100 for buy, sell in zip(buy_prices, sell_prices)]

    # Separate percentage changes into success and loss
    success_percentages = [p for p in trade_percentages if p > 0]
    loss_percentages = [p for p in trade_percentages if p < 0]

    # Calculate average success and loss percentages
    average_success_percentage = np.mean(success_percentages) if success_percentages else 0
    average_loss_percentage = np.mean(loss_percentages) if loss_percentages else 0

    return average_success_percentage, average_loss_percentage


def get_market_cap(symbol):
    def fetch_market_cap(ticker_symbol):
        try:
            ticker = yf.Ticker(ticker_symbol)
            info = ticker.info
            market_cap = info.get('marketCap')
            return market_cap
        except Exception:
            return None

    market_cap = fetch_market_cap(symbol + '.NS')

    if market_cap is None:
        market_cap = fetch_market_cap(symbol + '.BO')

    if market_cap is None:
        return -1

    # Convert market cap to crores (1 crore = 10 million)
    market_cap_in_crores = market_cap / 10**7
    return market_cap_in_crores

# %%
stocks_df=pd.read_csv('STOCKS_1.csv')
stocks_df = stocks_df.dropna(subset=['Symbol'])
stocks=stocks_df['Symbol']

# %%
from tqdm import tqdm
all_stocks_data = []  # Initialize an empty list to store individual stock data
total_stocks = len(stocks)
failed_stocks=[]
success_stocks=[]

multipliers = np.arange(1.5, 3.5, 0.5)
periods = np.arange(7, 22, 1)

for stock in tqdm(stocks, desc="Fetching data", unit="stock"):
    try:
        df,symbol = DataFetcher(stock)
        best_params = optimize_super_trend_parameters(df.copy(), multipliers, periods)
        temp_df = calculate_super_trend(df, best_params[0], best_params[1])
        profit_percentage = calculate_profit_percentage(temp_df)
        average_trade_percentage = calculate_trade_percentages(temp_df)
        all_stocks_data.append({'symbol': symbol, 'multiplier': best_params[0], 'period': best_params[1],'average_success_percentage' : average_trade_percentage[0],'average_loss_percentage' : average_trade_percentage[1], 'percentage': profit_percentage, 'Market Cap cr' : get_market_cap(stock)})
        success_stocks.append(stock)
    except Exception as e:
        failed_stocks.append(stock)
        continue

all_stocks_df = pd.DataFrame(all_stocks_data)  # Concatenate all stock dataframes
# Out:
# Fetching data:  16%|█▌        | 350/2227 [56:19<6:35:14, 12.63s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MOSMALL250.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MOSMALL250.BO&crumb=F5wWXGWg1Cw
# Fetching data:  20%|██        | 455/2227 [1:14:14<4:11:08,  8.50s/stock]
# 1 Failed download:
# ['NIFTYCONSURDURBL.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  26%|██▋       | 589/2227 [1:39:25<6:28:00, 14.21s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NPBET.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NPBET.BO&crumb=F5wWXGWg1Cw
# Fetching data:  27%|██▋       | 603/2227 [1:42:23<7:58:35, 17.68s/stock]
# 1 Failed download:
# ['NIFTYFINSERVICE.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  33%|███▎      | 736/2227 [2:04:43<4:16:02, 10.30s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AXISBNKETF.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AXISBNKETF.BO&crumb=F5wWXGWg1Cw
# Fetching data:  34%|███▎      | 747/2227 [2:06:13<3:50:44,  9.35s/stock]
# 1 Failed download:
# ['BANKNIFTY.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  34%|███▍      | 764/2227 [2:08:43<2:41:33,  6.63s/stock]
# 1 Failed download:
# ['NIFTYMIDSELECT.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  35%|███▍      | 774/2227 [2:10:49<6:00:01, 14.87s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SDL26BEES.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SDL26BEES.BO&crumb=F5wWXGWg1Cw
# Fetching data:  35%|███▍      | 778/2227 [2:11:11<3:29:12,  8.66s/stock]
# 1 Failed download:
# ['CNXSMALLCAP.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  36%|███▋      | 808/2227 [2:16:15<2:35:11,  6.56s/stock]
# 1 Failed download:
# ['NIFTYMIDCAP50.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  37%|███▋      | 816/2227 [2:17:10<2:17:35,  5.85s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SBIETFQLTY.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SBIETFQLTY.BO&crumb=F5wWXGWg1Cw
# Fetching data:  37%|███▋      | 835/2227 [2:19:57<4:03:36, 10.50s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MID150BEES.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MID150BEES.BO&crumb=F5wWXGWg1Cw
# Fetching data:  38%|███▊      | 856/2227 [2:24:10<5:14:13, 13.75s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NIF10GETF.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NIF10GETF.BO&crumb=F5wWXGWg1Cw
# Fetching data:  41%|████▏     | 922/2227 [2:35:07<3:51:24, 10.64s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/EBBETF0433.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=EBBETF0433.BO&crumb=F5wWXGWg1Cw
# Fetching data:  44%|████▍     | 987/2227 [2:44:02<3:54:39, 11.35s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SBIETFPB.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SBIETFPB.BO&crumb=F5wWXGWg1Cw
# Fetching data:  44%|████▍     | 990/2227 [2:44:26<2:58:43,  8.67s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MONIFTY500.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MONIFTY500.BO&crumb=F5wWXGWg1Cw
# Fetching data:  45%|████▌     | 1012/2227 [2:47:11<1:32:54,  4.59s/stock]
# 1 Failed download:
# ['CNXNIFTYJUNIOR.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  46%|████▋     | 1032/2227 [2:50:58<2:56:28,  8.86s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SETF10GILT.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SETF10GILT.BO&crumb=F5wWXGWg1Cw
# Fetching data:  47%|████▋     | 1047/2227 [2:52:57<2:06:53,  6.45s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AXISBPSETF.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AXISBPSETF.BO&crumb=F5wWXGWg1Cw
# Fetching data:  47%|████▋     | 1051/2227 [2:53:22<2:08:42,  6.57s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GSEC10IETF.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GSEC10IETF.BO&crumb=F5wWXGWg1Cw
# Fetching data:  48%|████▊     | 1059/2227 [2:54:31<2:56:36,  9.07s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MIDCAP.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MIDCAP.BO&crumb=F5wWXGWg1Cw
# Fetching data:  48%|████▊     | 1067/2227 [2:56:08<4:01:49, 12.51s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ALPHA.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ALPHA.BO&crumb=F5wWXGWg1Cw
# Fetching data:  48%|████▊     | 1075/2227 [2:57:12<2:48:46,  8.79s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LTGILTBEES.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LTGILTBEES.BO&crumb=F5wWXGWg1Cw
# Fetching data:  48%|████▊     | 1077/2227 [2:57:21<1:57:36,  6.14s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PHARMABEES.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PHARMABEES.BO&crumb=F5wWXGWg1Cw
# Fetching data:  49%|████▉     | 1086/2227 [2:58:31<2:38:28,  8.33s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/EBBETF0430.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=EBBETF0430.BO&crumb=F5wWXGWg1Cw
# Fetching data:  49%|████▉     | 1089/2227 [2:58:42<1:33:27,  4.93s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LIQUIDADD.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LIQUIDADD.BO&crumb=F5wWXGWg1Cw
# Fetching data:  49%|████▉     | 1091/2227 [2:58:45<58:31,  3.09s/stock]  404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LIQUID1.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LIQUID1.BO&crumb=F5wWXGWg1Cw
# Fetching data:  49%|████▉     | 1094/2227 [2:58:54<54:05,  2.86s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LIQUIDCASE.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LIQUIDCASE.BO&crumb=F5wWXGWg1Cw
# Fetching data:  49%|████▉     | 1102/2227 [2:59:55<2:52:38,  9.21s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AXISNIFTY.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AXISNIFTY.BO&crumb=F5wWXGWg1Cw
# Fetching data:  50%|████▉     | 1106/2227 [3:00:34<2:42:39,  8.71s/stock]
# 1 Failed download:
# ['NIFTY.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  50%|████▉     | 1109/2227 [3:00:49<1:56:36,  6.26s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/HDFCLIQUID.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=HDFCLIQUID.BO&crumb=F5wWXGWg1Cw
# Fetching data:  50%|████▉     | 1112/2227 [3:01:10<2:08:03,  6.89s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABSLLIQUID.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABSLLIQUID.BO&crumb=F5wWXGWg1Cw
# Fetching data:  50%|████▉     | 1113/2227 [3:01:13<1:48:17,  5.83s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LIQUID.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LIQUID.BO&crumb=F5wWXGWg1Cw
# Fetching data:  50%|█████     | 1114/2227 [3:01:16<1:33:54,  5.06s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LIQUIDSBI.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LIQUIDSBI.BO&crumb=F5wWXGWg1Cw
# Fetching data:  50%|█████     | 1115/2227 [3:01:19<1:20:28,  4.34s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LIQUIDBETF.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LIQUIDBETF.BO&crumb=F5wWXGWg1Cw
# Fetching data:  50%|█████     | 1116/2227 [3:01:21<1:06:48,  3.61s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LIQUIDIETF.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LIQUIDIETF.BO&crumb=F5wWXGWg1Cw
# Fetching data:  50%|█████     | 1121/2227 [3:01:49<1:32:33,  5.02s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GSEC10ABSL.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GSEC10ABSL.BO&crumb=F5wWXGWg1Cw
# Fetching data:  51%|█████     | 1133/2227 [3:02:41<1:13:26,  4.03s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TATAGOLD.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TATAGOLD.BO&crumb=F5wWXGWg1Cw
# Fetching data:  52%|█████▏    | 1150/2227 [3:04:52<2:57:33,  9.89s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SETFNN50.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SETFNN50.BO&crumb=F5wWXGWg1Cw
# Fetching data:  52%|█████▏    | 1159/2227 [3:06:11<2:16:39,  7.68s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/IVZINNIFTY.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=IVZINNIFTY.BO&crumb=F5wWXGWg1Cw
# Fetching data:  52%|█████▏    | 1169/2227 [3:07:45<2:47:30,  9.50s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LICNETFGSC.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LICNETFGSC.BO&crumb=F5wWXGWg1Cw
# Fetching data:  53%|█████▎    | 1178/2227 [3:09:00<1:39:03,  5.67s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LOWVOL1.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LOWVOL1.BO&crumb=F5wWXGWg1Cw
# Fetching data:  53%|█████▎    | 1179/2227 [3:09:03<1:24:38,  4.85s/stock]
# 1 Failed download:
# ['NIFTYHEALTHCARE.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  53%|█████▎    | 1187/2227 [3:10:35<3:49:08, 13.22s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABGSEC.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABGSEC.BO&crumb=F5wWXGWg1Cw
# Fetching data:  54%|█████▎    | 1194/2227 [3:11:30<2:02:17,  7.10s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/EGOLD.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=EGOLD.BO&crumb=F5wWXGWg1Cw
# Fetching data:  54%|█████▍    | 1213/2227 [3:14:34<1:31:12,  5.40s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SBIETFCON.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SBIETFCON.BO&crumb=F5wWXGWg1Cw
# Fetching data:  55%|█████▌    | 1229/2227 [3:16:32<1:49:33,  6.59s/stock]
# 1 Failed download:
# ['NIFTYCONSUMPTION.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  56%|█████▌    | 1244/2227 [3:18:46<2:38:08,  9.65s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TNIDETF.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TNIDETF.BO&crumb=F5wWXGWg1Cw
# Fetching data:  56%|█████▌    | 1252/2227 [3:19:44<1:45:57,  6.52s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GSEC10YEAR.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GSEC10YEAR.BO&crumb=F5wWXGWg1Cw
# Fetching data:  56%|█████▋    | 1254/2227 [3:20:05<2:29:19,  9.21s/stock]
# 1 Failed download:
# ['NIFTYDIVOPPS50.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  57%|█████▋    | 1268/2227 [3:22:22<2:50:15, 10.65s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/DIVOPPBEES.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=DIVOPPBEES.BO&crumb=F5wWXGWg1Cw
# Fetching data:  57%|█████▋    | 1272/2227 [3:22:46<2:10:23,  8.19s/stock]
# 1 Failed download:
# ['NIFTY50VALUE20.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  59%|█████▉    | 1310/2227 [3:29:29<1:29:20,  5.85s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CONSUMBEES.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CONSUMBEES.BO&crumb=F5wWXGWg1Cw
# Fetching data:  59%|█████▉    | 1319/2227 [3:31:28<3:58:30, 15.76s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NV20BEES.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NV20BEES.BO&crumb=F5wWXGWg1Cw
# Fetching data:  59%|█████▉    | 1325/2227 [3:32:27<2:44:19, 10.93s/stock]
# 1 Failed download:
# ['NIFTYGROWSECT15.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  60%|█████▉    | 1328/2227 [3:32:50<2:16:10,  9.09s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/BBETF0432.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=BBETF0432.BO&crumb=F5wWXGWg1Cw
# Fetching data:  62%|██████▏   | 1370/2227 [3:40:54<3:23:43, 14.26s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GSEC5IETF.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GSEC5IETF.BO&crumb=F5wWXGWg1Cw
# Fetching data:  62%|██████▏   | 1378/2227 [3:42:06<2:41:43, 11.43s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SDL24BEES.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SDL24BEES.BO&crumb=F5wWXGWg1Cw
# Fetching data:  62%|██████▏   | 1388/2227 [3:43:33<2:03:57,  8.86s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MOREALTY.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MOREALTY.BO&crumb=F5wWXGWg1Cw
# Fetching data:  62%|██████▏   | 1391/2227 [3:44:05<2:36:32, 11.24s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AUTOBEES.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AUTOBEES.BO&crumb=F5wWXGWg1Cw
# Fetching data:  63%|██████▎   | 1404/2227 [3:46:00<2:43:29, 11.92s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/IDFNIFTYET.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=IDFNIFTYET.BO&crumb=F5wWXGWg1Cw
# Fetching data:  63%|██████▎   | 1409/2227 [3:46:49<2:38:24, 11.62s/stock]
# 1 Failed download:
# ['NIFTYPSUBANK.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  63%|██████▎   | 1413/2227 [3:47:28<2:36:25, 11.53s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SBIETFIT.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SBIETFIT.BO&crumb=F5wWXGWg1Cw
# Fetching data:  64%|██████▎   | 1419/2227 [3:48:15<2:08:52,  9.57s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KSHITIJPOL.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KSHITIJPOL.BO&crumb=F5wWXGWg1Cw
# Fetching data:  64%|██████▍   | 1425/2227 [3:49:30<3:02:53, 13.68s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MOGSEC.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MOGSEC.BO&crumb=F5wWXGWg1Cw
# Fetching data:  67%|██████▋   | 1493/2227 [3:59:16<1:49:59,  8.99s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SILVERBEES.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SILVERBEES.BO&crumb=F5wWXGWg1Cw
# Fetching data:  67%|██████▋   | 1494/2227 [3:59:20<1:33:22,  7.64s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ITBEES.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ITBEES.BO&crumb=F5wWXGWg1Cw
# Fetching data:  68%|██████▊   | 1514/2227 [4:03:29<2:42:49, 13.70s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TATSILV.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TATSILV.BO&crumb=F5wWXGWg1Cw
# Fetching data:  68%|██████▊   | 1520/2227 [4:04:14<1:48:17,  9.19s/stock]
# 1 Failed download:
# ['NIFTYCOMMODITIES.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  68%|██████▊   | 1522/2227 [4:04:33<1:59:42, 10.19s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MNC.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MNC.BO&crumb=F5wWXGWg1Cw
# Fetching data:  68%|██████▊   | 1523/2227 [4:04:37<1:36:17,  8.21s/stock]
# 1 Failed download:
# ['NIFTYOILANDGAS.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  70%|██████▉   | 1549/2227 [4:08:29<1:43:00,  9.12s/stock]
# 1 Failed download:
# ['NIFTYMETAL.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data:  71%|███████   | 1576/2227 [4:12:23<1:32:39,  8.54s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NIF5GETF.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NIF5GETF.BO&crumb=F5wWXGWg1Cw
# Fetching data:  71%|███████▏  | 1589/2227 [4:14:22<1:00:37,  5.70s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SILVER1.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SILVER1.BO&crumb=F5wWXGWg1Cw
# Fetching data:  73%|███████▎  | 1620/2227 [4:21:15<2:43:44, 16.18s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AXISILVER.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AXISILVER.BO&crumb=F5wWXGWg1Cw
# Fetching data:  74%|███████▎  | 1637/2227 [4:24:04<1:50:31, 11.24s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ESILVER.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ESILVER.BO&crumb=F5wWXGWg1Cw
# Fetching data:  78%|███████▊  | 1737/2227 [4:41:00<1:02:39,  7.67s/stock]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/JAIPURKURT.BO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=JAIPURKURT.BO&crumb=F5wWXGWg1Cw
# Fetching data:  85%|████████▍ | 1890/2227 [5:08:49<1:07:13, 11.97s/stock]
# 1 Failed download:
# ['NIFTYMEDIA.NS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Fetching data: 100%|██████████| 2227/2227 [6:06:48<00:00,  9.88s/stock]

# %%
csv_file_path = 'Paramns_stocks.csv'
all_stocks_df.to_csv(csv_file_path, index=False)
